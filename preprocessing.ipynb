# %% [markdown]
# # KHÁM PHÁ VÀ TIỀN XỬ LÝ DỮ LIỆU

# %% [markdown]
# ## Import thư viện cần thiết

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Thu thập dữ liệu

# %% [markdown]
# ### Thông tin chung

# %% [markdown]
# - **Chủ đề dữ liệu**: Thông tin về Anime (Phim hoạt hình Nhật Bản)
# - **Cách thu thập dữ liệu**: Bộ dữ liệu được thu thập từ nền tảng MyAnimeList, một cộng đồng và cơ sở dữ liệu trực tuyến phổ biến dành cho những người đam mê anime và manga. Nền tảng này cung cấp thông tin về các anime, hồ sơ người dùng và điểm của người dùng đánh giá cho các anime khác nhau. Chúng em sử dụng ngôn ngữ lập trình Python, cùng Selenium để trích xuất dữ liệu từ web.

# %% [markdown]
# ## Khám phá và tiền xử lý dữ liệu

# %% [markdown]
# ### Đọc dữ liệu từ file csv

# %%
anime_df = pd.read_csv('animes.csv')

# %% [markdown]
# #### Hiển thị 5 hàng đầu tiên trong tập dữ liệu

# %%
anime_df.head()
# Out:
#     ID                            Title Episodes   Type  \
# 0  1.0                     Cowboy Bebop       26     TV
# 1  5.0  Cowboy Bebop: Tengoku no Tobira        1  Movie
# 2  6.0                           Trigun       26     TV
# 3  7.0               Witch Hunter Robin       26     TV
# 4  8.0                   Bouken Ou Beet       52     TV
#
#                           Aired                                    Producers  \
# 0   Apr 3, 1998 to Apr 24, 1999                                Bandai Visual
# 1                   Sep 1, 2001                       Sunrise, Bandai Visual
# 2   Apr 1, 1998 to Sep 30, 1998                         Victor Entertainment
# 3   Jul 3, 2002 to Dec 25, 2002  Bandai Visual, Dentsu, Victor Entertainment
# 4  Sep 30, 2004 to Sep 29, 2005                             TV Tokyo, Dentsu
#
#           Studios    Source                                Genres  \
# 0         Sunrise  Original         Action, Award Winning, Sci-Fi
# 1           Bones  Original                        Action, Sci-Fi
# 2        Madhouse     Manga             Action, Adventure, Sci-Fi
# 3         Sunrise  Original  Action, Drama, Mystery, Supernatural
# 4  Toei Animation     Manga            Action, Adventure, Fantasy
#
#           Duration  Score  Rating count   Rank  Popularity
# 0  24 min. per ep.   8.75      988000.0    482        43.0
# 1    1 hr. 55 min.   8.38      219779.0   2092       631.0
# 2  24 min. per ep.   8.22      380049.0   3602       258.0
# 3  25 min. per ep.   7.24       44600.0  30982      1908.0
# 4  23 min. per ep.   6.93        6891.0  45862      5485.0

# %% [markdown]
# ### Số hàng và số cột của tập dữ liệu

# %%
nrows, ncols = anime_df.shape
print('Số hàng của dataset:', nrows)
print('Số cột của dataset:', ncols)
# Out:
# Số hàng của dataset: 25012
# Số cột của dataset: 14

# %% [markdown]
# ### Ý nghĩa của mỗi hàng

# %% [markdown]
# Mỗi hàng chứa thông tin về 1 bộ anime như tên, thể loại, số tập, thời lượng, nhà sản xuất,... và xếp hạng dựa trên một số tiêu chí cũng như là điểm đánh giá trung bình cho anime đó do người dùng đánh giá trên nền tảng MyAnimeList.

# %% [markdown]
# ### Loại bỏ những hàng không có dữ liệu

# %%
anime_df.dropna(how='all', inplace=True)

# %% [markdown]
# ### Loại bỏ những hàng trùng lặp

# %%
num_duplicates = anime_df.duplicated().sum()
print(f"Số hàng trùng lặp: {num_duplicates}")
# Out:
# Số hàng trùng lặp: 19

# %%
anime_df = anime_df.drop_duplicates()

# %%
nrows, ncols = anime_df.shape
print('Số hàng của dataset sau khi xử lý:', nrows)
# Out:
# Số hàng của dataset sau khi xử lý: 24990

# %% [markdown]
# ### Ý nghĩa của mỗi cột

# %%
# Xem tên của từng cột
anime_df.columns
# Out:
# Index(['ID', 'Title', 'Episodes', 'Type', 'Aired', 'Producers', 'Studios',
#        'Source', 'Genres', 'Duration', 'Score', 'Rating count', 'Rank',
#        'Popularity'],
#       dtype='object')

# %% [markdown]
# #### Ý nghĩa của mỗi cột:
# - Cột đầu tiên cho biết ID của anime (ID)
# - Cột thứ 2 cho biết tên gốc của anime (Title)
# - Cột thứ 3 cho biết số tập của anime (Episodes)
# - Cột thứ 4 cho biết anime thuộc dạng phim dài tập hay movie,... (Type)
# - Cột thứ 5 cho biết ngày bắt đầu và kết thúc việc phát sóng anime (Aired)
# - Cột thứ 6 cho biết công ty hoặc nhà sản xuất của anime (Producers)
# - Cột thứ 7 cho biết hãng làm phim hoạt hình làm ra anime (Studios)
# - Cột thứ 8 cho biết nguồn tài liệu để làm ra anime (Source)
# - Cột thứ 9 cho biết thể loại của anime, một anime có thể thuộc nhiều thể loại được phân tách bởi dấu phẩy (Genres)
# - Cột thứ 10 cho biết thời lượng của mỗi tập trong anime (Duration)
# - Cột thứ 11 cho biết điểm số trung bình đánh giá cho anime bởi người dùng (Score)
# - Cột thứ 12 cho biết số lượng người dùng đã chấm điểm cho anime (Rating count)
# - Cột thứ 13 cho biết xếp hạng của anime dựa trên Score, nếu cùng điểm sẽ so sánh các tiêu chí khác (Rank)
# - Cột thứ 14 cho biết xếp hạng độ phổ biến của anime (Popularity)

# %% [markdown]
# Cột thứ 12 cho biết số lượng người dùng đã chấm điểm cho anime nhưng có tên Rating count chưa phù hợp lắm nên ta sẽ đổi tên cột thành Scored By.

# %%
anime_df.rename(columns={'Rating count': 'Scored By'}, inplace=True)

# %%
anime_df.head()
# Out:
#     ID                            Title Episodes   Type  \
# 0  1.0                     Cowboy Bebop       26     TV
# 1  5.0  Cowboy Bebop: Tengoku no Tobira        1  Movie
# 2  6.0                           Trigun       26     TV
# 3  7.0               Witch Hunter Robin       26     TV
# 4  8.0                   Bouken Ou Beet       52     TV
#
#                           Aired                                    Producers  \
# 0   Apr 3, 1998 to Apr 24, 1999                                Bandai Visual
# 1                   Sep 1, 2001                       Sunrise, Bandai Visual
# 2   Apr 1, 1998 to Sep 30, 1998                         Victor Entertainment
# 3   Jul 3, 2002 to Dec 25, 2002  Bandai Visual, Dentsu, Victor Entertainment
# 4  Sep 30, 2004 to Sep 29, 2005                             TV Tokyo, Dentsu
#
#           Studios    Source                                Genres  \
# 0         Sunrise  Original         Action, Award Winning, Sci-Fi
# 1           Bones  Original                        Action, Sci-Fi
# 2        Madhouse     Manga             Action, Adventure, Sci-Fi
# 3         Sunrise  Original  Action, Drama, Mystery, Supernatural
# 4  Toei Animation     Manga            Action, Adventure, Fantasy
#
#           Duration  Score  Scored By   Rank  Popularity
# 0  24 min. per ep.   8.75   988000.0    482        43.0
# 1    1 hr. 55 min.   8.38   219779.0   2092       631.0
# 2  24 min. per ep.   8.22   380049.0   3602       258.0
# 3  25 min. per ep.   7.24    44600.0  30982      1908.0
# 4  23 min. per ep.   6.93     6891.0  45862      5485.0

# %% [markdown]
# ### Kiểu dữ liệu hiện tại của mỗi cột là gì? Có cột nào có kiểu dữ liệu không phù hợp không?

# %% [markdown]
# Ta sẽ thử xem xét các kiểu dữ liệu của của từng cột đã phù hợp chưa.

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24990 entries, 0 to 25011
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          24990 non-null  float64
#  1   Title       24990 non-null  object
#  2   Episodes    24990 non-null  object
#  3   Type        24990 non-null  object
#  4   Aired       24990 non-null  object
#  5   Producers   24990 non-null  object
#  6   Studios     24990 non-null  object
#  7   Source      24990 non-null  object
#  8   Genres      10879 non-null  object
#  9   Duration    24990 non-null  object
#  10  Score       16943 non-null  float64
#  11  Scored By   16943 non-null  float64
#  12  Rank        24990 non-null  object
#  13  Popularity  24990 non-null  float64
# dtypes: float64(4), object(10)
# memory usage: 2.9+ MB

# %% [markdown]
# Sau khi xem qua các cột dữ liệu ta thấy các cột nên có dữ liệu dạng số nhưng lại có dữ liệu object là:
# - Episodes
# - Rank
#
# Do đó ta sẽ chuẩn hóa kiểu dữ liệu cho các cột này về dạng số.

# %%
col_convert = ['Episodes', 'Rank']
for col in col_convert:
    anime_df[col] = pd.to_numeric(anime_df[col], errors='coerce')

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24990 entries, 0 to 25011
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          24990 non-null  float64
#  1   Title       24990 non-null  object
#  2   Episodes    24725 non-null  float64
#  3   Type        24990 non-null  object
#  4   Aired       24990 non-null  object
#  5   Producers   24990 non-null  object
#  6   Studios     24990 non-null  object
#  7   Source      24990 non-null  object
#  8   Genres      10879 non-null  object
#  9   Duration    24990 non-null  object
#  10  Score       16943 non-null  float64
#  11  Scored By   16943 non-null  float64
#  12  Rank        19849 non-null  float64
#  13  Popularity  24990 non-null  float64
# dtypes: float64(6), object(8)
# memory usage: 2.9+ MB

# %% [markdown]
# Các kiểu dữ liệu còn lại đã phù hợp với nội dung nên ta sẽ tiếp tục phần tiếp theo

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số, các giá trị được phân bố như thế nào?

# %% [markdown]
# #### Đầu tiên ta sẽ lấy tên các cột có dữ liệu dạng số và lưu vào `numeric_columns`

# %%
numeric_columns = anime_df.select_dtypes(include='number').columns[:] 
numeric_columns
# Out:
# Index(['ID', 'Episodes', 'Score', 'Scored By', 'Rank', 'Popularity'], dtype='object')

# %% [markdown]
# #### Sau đó, ta sẽ xem tỉ lệ giá trị bị thiếu trong các cột dữ liệu kiểu số là bao nhiêu:

# %%
percentage_missing_dic = {}
for col in numeric_columns:
    percentage_missing = anime_df[col].isna().mean() * 100
    percentage_missing_dic[col] = percentage_missing
    print(f'Phần trăm giá trị còn thiếu của cột \'{col}\' là {percentage_missing:.2f}%')
# Out:
# Phần trăm giá trị còn thiếu của cột 'ID' là 0.00%
# Phần trăm giá trị còn thiếu của cột 'Episodes' là 1.06%
# Phần trăm giá trị còn thiếu của cột 'Score' là 32.20%
# Phần trăm giá trị còn thiếu của cột 'Scored By' là 32.20%
# Phần trăm giá trị còn thiếu của cột 'Rank' là 20.57%
# Phần trăm giá trị còn thiếu của cột 'Popularity' là 0.00%

# %% [markdown]
# Sau khi xem qua ta thấy Score và Scored By là các cột có nhiều giá trị bị thiếu nhất. Tuy nhiên tỉ lệ giá trị bị thiếu của các cột này chưa đến 50%, hơn nữa hai cột này có nhiều giá trị trong quá trình tính toán nên chúng em sẽ chọn giữ lại nó trong bước tiền xử lý dữ liệu.

# %% [markdown]
# #### Tiếp theo ta xem qua mô tả của các cột có dữ liệu dạng số xem có gì bất thường không (tối thiểu, tối đa)

# %%
anime_df.describe()
# Out:
#                  ID      Episodes         Score     Scored By           Rank  \
# count  24990.000000  24725.000000  16943.000000  1.694300e+04   19849.000000
# mean   30411.921128     14.950617      6.398052  2.984130e+04  104564.428838
# std    18427.199078     49.519797      0.892995  1.182212e+05   61002.392085
# min        1.000000      1.000000      1.880000  1.030000e+02      12.000000
# 25%    10562.250000      1.000000      5.780000  3.715000e+02   51852.000000
# 50%    35258.500000      2.000000      6.380000  1.673000e+03  103702.000000
# 75%    46053.750000     13.000000      7.040000  1.052350e+04  156392.000000
# max    57179.000000   3057.000000      9.320000  2.858563e+06  211302.000000
#
#          Popularity
# count  24990.000000
# mean   13290.988756
# std     7780.432629
# min        1.000000
# 25%     6565.750000
# 50%    13173.500000
# 75%    19932.500000
# max    27166.000000

# %% [markdown]
# Ta xem xét từng cột và nhận xét:
# - ID có giá trị từ 1 đến 57179 mặc dù số lượng anime là 24990, vậy nên ta có thể suy ra ID của các anime là không liên tục.
# - Cột Score có giá trị từ 1.88 đến 9.32 đây là 1 khoảng hợp lý cho đánh giá điểm số của anime, không có anime nào 10 và không có anime bị đánh giá 0 điểm. Điểm trung bình của các anime nằm quanh khoảng 6.4, với phần lớn từ 5 đến 7.
# - Số lượng tập có sự chênh lệch lớn giữa các anime.
# - Độ phổ biến và số lượng người đánh giá cho thấy có sự chênh lệch đáng kể về mức độ phổ biến giữa các anime.
# - Các cột đều có khoảng giá trị phù hợp với ý nghĩa của từng cột.

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng phân loại, các giá trị được phân bố như thế nào?

# %% [markdown]
# Ở phần này sẽ có 2 dạng:
# - Cột có giá trị đơn: Title, Type, Source.
# - Cột có nhiều giá trị: Genres, Producers, Studios

# %% [markdown]
# #### Do đó đầu tiên ta sẽ xử lý trên các cột đơn trước

# %% [markdown]
# Đầu tiên lưu tên các cột có một giá trị vào `single_columns`

# %%
single_columns = ['Title', 'Type', 'Source', 'Duration', 'Aired']

# %% [markdown]
# Sau đó tính phần trăm giá trị còn thiếu của mỗi cột này

# %% [markdown]
# Ở bộ dữ liệu này các dữ liệu `NULL` đang được đánh dấu bằng nhiều chuỗi string khác nhau như: `Unknown`, `Not available`, `None found, add some`. Do đó ta sẽ thay thế các giá trị trên cũng như cả các dữ liệu `NULL` bằng một giá trị nhất quán `UNKNOWN` để đánh dấu các giá trị bị thiếu.

# %%
values_to_replace = ["Unknown", "Not available", "None found, add some", np.nan]

# Thay thế các giá trị không mong muốn bằng "UNKNOWN"
for column in anime_df.columns:     
    if anime_df[column].dtype == "object":
        anime_df[column] = anime_df[column].replace(values_to_replace, "UNKNOWN")

# %%
for col in single_columns:
    percentage_missing = (anime_df[col] == 'UNKNOWN').mean() * 100
    percentage_missing_dic[col] = percentage_missing
    print(f'Phần trăm giá trị còn thiếu của cột \'{col}\' là {percentage_missing:.2f}%')
# Out:
# Phần trăm giá trị còn thiếu của cột 'Title' là 0.00%
# Phần trăm giá trị còn thiếu của cột 'Type' là 0.12%
# Phần trăm giá trị còn thiếu của cột 'Source' là 11.22%
# Phần trăm giá trị còn thiếu của cột 'Duration' là 1.35%
# Phần trăm giá trị còn thiếu của cột 'Aired' là 2.88%

# %% [markdown]
# Ta thấy các cột này có giá trị thiếu rất ít có thể do các dữ liệu này là các thông tin cơ bản của một anime nên hầu như tất cả các anime được sản xuất đều phải có các thông tin này

# %% [markdown]
# Lưu số lượng giá trị khác nhau và đếm số lượng từng loại và lưu vào mảng `single_cate_profile`

# %%
single_cate_profile = pd.DataFrame(index=["num_diff_vals", "distribution"])
num_diff_vals = anime_df[single_columns].nunique()
distribution = anime_df[single_columns].agg(lambda column: pd.Series(column).value_counts().to_dict())
single_cate_profile[single_columns] = [num_diff_vals, distribution]

single_cate_profile
# Out:
#                                                            Title  \
# num_diff_vals                                              24989
# distribution   {'Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian': 2...
#
#                                                             Type  \
# num_diff_vals                                                 10
# distribution   {'TV': 7552, 'Movie': 4335, 'OVA': 4006, 'ONA'...
#
#                                                           Source  \
# num_diff_vals                                                 17
# distribution   {'Original': 10265, 'Manga': 4891, 'UNKNOWN': ...
#
#                                                         Duration  \
# num_diff_vals                                                331
# distribution   {'24 min. per ep.': 1987, '23 min. per ep.': 1...
#
#                                                            Aired
# num_diff_vals                                              15596
# distribution   {'UNKNOWN': 719, '2012 to ?': 74, '2005': 72, ...

# %% [markdown]
# Các cột đều có giá trị không có gì bất thường. Riêng cột Title có số giá trị ít hơn số hàng của bộ dữ liệu (24990 hàng). Ta sẽ in thử distribution ở cột Title để xem.

# %%
single_cate_profile.loc['distribution','Title']
# Out:
# {'Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian': 2,
#  'Cowboy Bebop': 1,
#  'Dokyuu Hentai HxEros OVA': 1,
#  'Mug': 1,
#  'Xin Yu Gong Yu Shan': 1,
#  'Black Channel': 1,
#  'Shokubutsu no Kimochi-hen': 1,
#  'Zone: Intro': 1,
#  'Shenmue the Animation': 1,
#  'MTV Town': 1,
#  'Tasuuketsu: Judgement Assizes': 1,
#  'Onegai Patron-sama!': 1,
#  'Execute': 1,
#  'Project Scard: Praeter no Kizu': 1,
#  'Gummies': 1,
#  'Wild Cleaner': 1,
#  'Nakado Riku Animation: Hijouyou Mochidashi Bukuro wo Youi Shiyou': 1,
#  'Sayonara Watashi no Cramer Movie: First Touch': 1,
#  'Rebirth: Virtual to no Souguu': 1,
#  'Jing: Shuang Cheng - Feng Qi Pian': 1,
#  'Carol (Music)': 1,
#  'Nijiiro Love Letter': 1,
#  'Sakura Kakumei: Hanasaku Otome-tachi': 1,
#  'Chicchana Photographer': 1,
#  'Kai Byoui Ramune': 1,
#  'Seijo no Maryoku wa Bannou desu': 1,
#  'Ashi': 1,
#  'Float': 1,
#  'Otona no Bouguya-san II': 1,
#  'Fudanshi Shoukan: Isekai de Shinjuu ni Hameraremashita': 1,
#  'Kotobadori (July 2019)': 1,
#  'Kotobadori': 1,
#  'Little Village People': 1,
#  'Shikoyaka Naru Toki mo Hameru Toki mo': 1,
#  'Ai no Utagoe wo Kikasete': 1,
#  'Sakura Melody': 1,
#  '23rd Japan Media Arts Festival Introduction': 1,
#  'I Love Tofu': 1,
#  'Boukyaku Battery': 1,
#  'Hanasaka Nyanko': 1,
#  'Young Alive!: iPS Saibou ga Hiraku Mirai': 1,
#  'Oto no Symphony': 1,
#  'Spark Da!': 1,
#  'This Is Not Blue': 1,
#  'Renwu Dashi': 1,
#  'Miao Qiansui de Chengnian Li': 1,
#  'Tales of Crestoria: Toga Waga wo Shoite Kare wa Tatsu': 1,
#  'Munou na Nana Mini Anime': 1,
#  'Hiyoko Buta no Theme Part 2.': 1,
#  'Hadakanbou': 1,
#  'Shu Ling Ji': 1,
#  'Dazzling White Town': 1,
#  'Xpice': 1,
#  'Moyashimon Returns: Kin Gekijou Shutchou-ban': 1,
#  'Sen no Hana Sen no Sora': 1,
#  'Deca-Dence: Install': 1,
#  'Ofuroya-san e Tsuretette': 1,
#  'Kaeru no Pickles: Kimochi no Iro': 1,
#  'Otona nya Koi no Shikata ga Wakaranee!': 1,
#  'Sore wo Ai to Yobu dake': 1,
#  'Microphone Soul Spinners: Kotodama Shoujo - Furikaeri Douga': 1,
#  'Nissan Note x The World of Golden Eggs': 1,
#  'Teinenpi Shoujo Heidi CMs': 1,
#  'Shiawase Kyou Ryuu Ondo': 1,
#  'Dokyuu Hentai HxEros: HxEros Report': 1,
#  'Beniimo Musume': 1,
#  'Bremen no Muppet Musician': 1,
#  'Rakuen Tsuihou: Faith Conquest': 1,
#  'Furimukeba Kaeru': 1,
#  'Princess Connect! Re:Dive Season 2': 1,
#  'Taisou Zamurai': 1,
#  'Mouseman: Ai no Katamari': 1,
#  'Kankan Karasu': 1,
#  'Kite': 1,
#  'My Graduation: Mirai': 1,
#  'Pocket no Naka de': 1,
#  'Baolie Feiche II: Xing Neng Juexing': 1,
#  'Boku no Me wa Neko no Me': 1,
#  'Re:Zero kara Hajimeru Isekai Seikatsu - Memory Snow Announcement': 1,
#  'Sayonara Watashi no Cramer': 1,
#  'Chii-chan no Himitsu': 1,
#  'Papa to Anata no Kageboushi': 1,
#  'Ji Jia Shou Shen 2nd Season': 1,
#  'Ji Jia Shou Shen': 1,
#  'Happy Happy Birthday': 1,
#  'Baolie Feiche 3: Shou Shen Heti': 1,
#  'White Blue': 1,
#  'Gigi Goegoe Sunghyungsoo': 1,
#  'Oneshota The Animation': 1,
#  'Hello Again, JoJo': 1,
#  "Love Live! μ's Go→Go! LoveLive! 2015: Dream Sensation!": 1,
#  'Kono Sekai no Tanoshimikata: Secret Story Film': 1,
#  'Watage no Osanpo': 1,
#  'Pure Shield': 1,
#  'Machikado Mazoku: 2-choume': 1,
#  'Deaerutte Ii ne': 1,
#  'Ji Jia Shou Shen: Baolie Feiche': 1,
#  'Ton Ton Ton': 1,
#  'Kanojo, Okarishimasu Petit': 1,
#  'Fanta Jiisan no Uta': 1,
#  'Uchuu Nanchara Kotetsu-kun': 1,
#  'Youjo Shachou': 1,
#  'Awajishima no Shichifukujin': 1,
#  "It's So Good Now": 1,
#  'Shocking Black': 1,
#  'Jashin-chan Dropkick X': 1,
#  'Dogeza de Tanondemita: Isekai-hen': 1,
#  'Magical Death': 1,
#  'New Tribe': 1,
#  'Ling Long: Incarnation Middle Chapter': 1,
#  'Gotcha!': 1,
#  'Idolls!': 1,
#  'Zhandou Wang Zhi Jufeng Zhan Hun 5: Heti Fanwai Pian': 1,
#  'Biohazard: Infinite Darkness': 1,
#  'Zoku Sayonara Zetsubou Sensei: Shuukan Zetsubou Sensei Hihyou': 1,
#  'Furusato (2013)': 1,
#  'Menghuan Shuyuan 4th Season': 1,
#  'Fei Zhi Baike': 1,
#  'Zhan Shuang Panini': 1,
#  'Kanojo, Okarishimasu 2nd Season': 1,
#  'Uzaki-chan wa Asobitai! Double': 1,
#  'Yatogame-chan Kansatsu Nikki Sansatsume': 1,
#  'Beef Stroganoff': 1,
#  'Ookina Onaka': 1,
#  'Osananajimi ga Zettai ni Makenai Love Comedy': 1,
#  'Gundam: G no Reconguista Movie IV - Gekitou ni Sakebu Ai': 1,
#  'Wuya Weisheme shi Hei de': 1,
#  'Shen Bi': 1,
#  'Hao Pengyou': 1,
#  'Xiaomei De Meng': 1,
#  'Kuakou de Qingwa': 1,
#  'Cai Mogu': 1,
#  'Xiexie Xiaohua Mao': 1,
#  'Onegai Patron-sama! Episode 0': 1,
#  'Gundam: G no Reconguista Movie V - Shisen wo Koete': 1,
#  'Gundam: G no Reconguista Movie III - Uchuu kara no Isan': 1,
#  'Yami Yami': 1,
#  'Huangdi Meng': 1,
#  'Alba': 1,
#  'Luotuo Xian Wu': 1,
#  'Yami Yami (September 2012)': 1,
#  'Yi Guan Xing Shen': 1,
#  'Chao Shen Z': 1,
#  'Words Worth Omake': 1,
#  'Isaku: Tsumi to Batsu': 1,
#  'Aku no Onna Kanbu: Full Moon Night R': 1,
#  'Uta no Uta': 1,
#  'Hanhua Riji 2nd Season': 1,
#  'Hallelujah: Unmei no Sentaku': 1,
#  'Akai Hoshi Aoi Hoshi: Tenmon Carat no Hoshi kara': 1,
#  'Wan Jie Xian Zong 4th Season': 1,
#  'Horimiya': 1,
#  'Mou Ii Kai': 1,
#  'Uchuu wa Tanoshii Festival': 1,
#  'Natsume Yuujinchou: Ishi Okoshi to Ayashiki Raihousha': 1,
#  'The God of High School PV': 1,
#  'Baraou no Souretsu': 1,
#  'Cap Kakumei Bottleman': 1,
#  'Muteki-kyuu*Believer / Mirai Harmony': 1,
#  'Door': 1,
#  'Watashi no Nyanko': 1,
#  'Ginga Eiyuu Densetsu: Die Neue These - Gekitotsu': 1,
#  'Zoids Wild Senki': 1,
#  'Sore dake ga Neck': 1,
#  'The iDOLM@STER Cinderella Girls: Starlight Stage - 5-shuunen Kinen "Go Just Go!" PV': 1,
#  'Yuu☆Yuu☆Hakusho: Eizou Hakusho - Opening Ending Encyclopedia': 1,
#  'Chou Futsuu Toshi Kashiwa Densetsu: Kashiwa no Gotouji Yuru Anime': 1,
#  'Chou Futsuu Toshi Kashiwa Densetsu: Ekimae Housou UDC2-hen': 1,
#  'Daijoubu': 1,
#  'Natsu Koibana': 1,
#  'My Little Goat': 1,
#  'Zetsubou no Kaibutsu': 1,
#  'Hige Hige Gehi Ponpon': 1,
#  'Sakugasaku': 1,
#  'Wo Wei Ge Kuang: Xuanlu Chongqi': 1,
#  'Wo Jia Da Shixiong Shi Ge Fanpai': 1,
#  'Shaonu Qianxian: Renxing Xiao Juchang 2': 1,
#  'Su Shen Xiao Ren': 1,
#  'Qin Xia': 1,
#  'Kusoge tte Iuna! Animation': 1,
#  'Uma Musume: Pretty Derby Season 2': 1,
#  'Hanma Baki: Son of Ogre': 1,
#  'Fruits Basket: The Final': 1,
#  'Kamu Kamo Shikamo Nidomo Kamo!': 1,
#  'Natsu wo Ikiru': 1,
#  'SK∞': 1,
#  'Q-Borg': 1,
#  'Funiculì funiculà': 1,
#  'Sword Art Online: Progressive Movie - Hoshi Naki Yoru no Aria': 1,
#  'Planetarium Pokemon: Aurora kara no Message': 1,
#  'Saezuru Doubutsu wa Yarushikanai!': 1,
#  'Nolaehago Sip-eo': 1,
#  'Padoga Kkeutnaneun Goskkaji': 1,
#  'Minami no Shima no Hanayome-san': 1,
#  'Fuusen': 1,
#  'Robocar Poli 4': 1,
#  'Dongguo Xiansheng': 1,
#  'Suisei ni Nareta Nara': 1,
#  'Dai 13-kai Indies Anime Festa OP': 1,
#  'Fusuma no Oku': 1,
#  'Senpai ga Uzai Kouhai no Hanashi': 1,
#  'Hakata Bus Terminal Blues': 1,
#  'Hakata Bus Terminal Gorou': 1,
#  'Get Up! Get Live! #GeraGera Episode 0': 1,
#  'Ame wo Matsu,': 1,
#  'Uchuu no Kishi Tekkaman Blade II: Virgin Memory': 1,
#  'Meikyuu Black Company': 1,
#  'Uchuu Ace Pilots': 1,
#  'Qing Chi Hong Xiaodou Ba! 4th Season': 1,
#  'Mengyou Dunhuang': 1,
#  'Renlei Bowuguan': 1,
#  'Sansan de Ezuoju Chufang': 1,
#  'Hei Mao Jing Zhang (2010)': 1,
#  'Represent Chikyuu Collab Anime': 1,
#  'Uwaki to Honki The Animation': 1,
#  'Nanjung Ilgi': 1,
#  'Battle Athletess Daiundoukai ReSTART!': 1,
#  'Liu Yi Chuanqi': 1,
#  'Mei Chuxi de Yinyangshi Yijia 2': 1,
#  'Real Koke-kun': 1,
#  'Zhen Hun Jie: Bei Luo Shi Men Pian Part 2': 1,
#  'Ijiranaide, Nagatoro-san': 1,
#  'Uracon III Opening Animation': 1,
#  'Date A Bullet: Nightmare or Queen': 1,
#  "Healin' Good♡Precure Movie: Yume no Machi de Kyun! Tto GoGo! Dai Henshin!!": 1,
#  'Eternity: Shinya no Nurekoi Channel ♡': 1,
#  'Heian Sento': 1,
#  'Honnouji no Hen': 1,
#  'Benkai to Ushiwakamaru': 1,
#  'Shakunetsu Kabaddi': 1,
#  'Grisaia: Phantom Trigger The Animation - Stargazer': 1,
#  'Osomatsu-san 3rd Season': 1,
#  'Hataraku Saibou!! Saikyou no Teki, Futatabi. Karada no Naka wa "Chou" Oosawagi!': 1,
#  'Re:Zero kara Hajimeru Break Time 2nd Season': 1,
#  'The iDOLM@STER Million Live!': 1,
#  'Konbini Shoujo Z': 1,
#  'Yuki no Furu Machi': 1,
#  'Re:I Am': 1,
#  'We Two': 1,
#  'Xiao Hua Xian 5th Season: Si Shi Huayu - Chun Xia': 1,
#  'Xiao Hua Xian 4th Season: Shou Hu Tian Shi 2': 1,
#  'Yasai no Yousei: N.Y. Salad Special': 1,
#  'Yasai no Yousei: N.Y. Salad The Movie': 1,
#  'Cosmos Trailer': 1,
#  'Who Am I?': 1,
#  'Ninjala': 1,
#  'Cyberpunk: Edgerunners': 1,
#  'Dubu Xiaoyao': 1,
#  'Wu Dong Qian Kun 2nd Season': 1,
#  'Konglong Baobei: Longshen Yongshi 3': 1,
#  'Konglong Baobei: Longshen Yongshi 2': 1,
#  'Enoshimans Spin-off: Kurage no Soudan': 1,
#  'Ninja Collection': 1,
#  'Spin': 1,
#  'Gavora': 1,
#  'Tonbo': 1,
#  'Bungou Stray Dogs Wan!': 1,
#  'Tokyo Revengers': 1,
#  'Eizou (Kage)': 1,
#  'Oumagatoki': 1,
#  'S=13': 1,
#  'Tiger Mask Pilot Film': 1,
#  'Refrain': 1,
#  'Ani ni Tsukeru Kusuri wa Nai! 4': 1,
#  'Princess Aya': 1,
#  'Ringo to Shoujo': 1,
#  'Suirin: Karma (Ni)': 1,
#  'Junkers Come Here Pilot Film': 1,
#  'Shouxi Yu Ling Shi': 1,
#  'Line': 1,
#  'Karasu': 1,
#  'Heukkkokdujanggun': 1,
#  'Subarashiki Kono Sekai The Animation': 1,
#  'Da Wang Bu Gaoxing 2': 1,
#  'Sollo Talchul Gwi': 1,
#  'Fushigi Dagashiya: Zenitendou Movie - Tsuri Taiyaki': 1,
#  'Fushigi Dagashiya: Zenitendou': 1,
#  'Qiang Shen Ji: Shenhai Xianluo Pian': 1,
#  'Son Ogong': 1,
#  'Xian Feng Jianyu Lu': 1,
#  'Ling Long: Incarnation Part 2': 1,
#  'Shi Zhi Ge: Hua Yu Yan De Kuangxiang Shi': 1,
#  'Kidou': 1,
#  'Yuan Long': 1,
#  'Otome Game no Hametsu Flag shika Nai Akuyaku Reijou ni Tensei shiteshimatta... X': 1,
#  'Zap Cat': 1,
#  'Lotus': 1,
#  'Wind': 1,
#  'The Third Eye': 1,
#  'Yellow Fish': 1,
#  'Rain: Memory of Cloud. 1': 1,
#  'Miminari': 1,
#  'Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen 3rd Season': 1,
#  'Kachou Fuugetsu (Music)': 1,
#  'Kyou kara Omoide': 1,
#  'Nemuri no Mori': 1,
#  'Boku no Hero Academia: Ikinokore! Kesshi no Survival Kunren': 1,
#  'Miloha CM: Oresama ni, Amae Chai na': 1,
#  'Opette': 1,
#  'Never Giving Up!': 1,
#  'Kesshouban: Eigakan e Iku': 1,
#  'Kaa-chan no Tomodachi ni Shikotteru Tokoro Mirareta. The Animation': 1,
#  'Toshoshitsu no Kanojo: Seiso na Kimi ga Ochiru made - The Animation': 1,
#  'Mashiro no Oto': 1,
#  'Yuuki Yuuna wa Yuusha de Aru: Dai Mankai no Shou': 1,
#  'Black Cat (Movie)': 1,
#  'Showtime': 1,
#  'Houkago Pilot': 1,
#  'Dogeza de Tanondemita': 1,
#  'Yaku nara Mug Cup mo': 1,
#  'Take It Easy': 1,
#  'Kyokou Uranai': 1,
#  'Huanji 45 Miao': 1,
#  'Hoshi ni Kataru Kyouryuu': 1,
#  'U-turn wa Wakai Uchi ni Shiro!': 1,
#  'Hulaing Babies Aratame - Staying Babies: Chikyuu wo Mamore! Staying Babies with Yuusha Hayami-san': 1,
#  'Kaizoku Oujo': 1,
#  'Yumemiru Jump': 1,
#  'Curry to Ieba': 1,
#  'Tokimeki': 1,
#  'Wan Sheng Jie 2': 1,
#  'Himitsukessha Taka no Tsume: Golden Spell': 1,
#  'Furusato': 1,
#  'Robocar Poli 3': 1,
#  'Aikatsu Planet!': 1,
#  'Ame Nochi Special': 1,
#  'Yuki Kagami': 1,
#  'Tooi Sora': 1,
#  'Shin Ougon Bat': 1,
#  'Mulan: Heng Kong Chu Shi': 1,
#  'Warabigami: Ten no Komoriuta': 1,
#  'White Lily Light': 1,
#  'Tsuki no Fuusen': 1,
#  'Don Pepe no Uta': 1,
#  'Tofu': 1,
#  'Yeon-ae Halujeon': 1,
#  'Yeon-ae Halujeon 2': 1,
#  'Mushi': 1,
#  'Peach Boy Riverside': 1,
#  'Heion Sedai no Idaten-tachi': 1,
#  'Jyou Jyou': 1,
#  'Pittarazu Gekijou Manner CM': 1,
#  'Pittarazu': 1,
#  'Teiketsu Bolt': 1,
#  'Menghuan Shuyuan: Youxue Ji': 1,
#  'Xiao Cangshu Di Di de Chi Bo Richang': 1,
#  'Wo De San Ti: Zhang Bei Hai Zhuan': 1,
#  'Xing You Ji: Fengbao Famila 2': 1,
#  'Gonfu Tu Yu Cai Bao Gou 2nd Season': 1,
#  'Gonfu Tu Yu Cai Bao Gou': 1,
#  'Wu Sheng Guan Gong': 1,
#  'Fei Ren Zai 1st Season Part 3': 1,
#  'Fei Ren Zai 1st Season Part 2': 1,
#  'Menghuan Shuyuan 3rd Season': 1,
#  'Menghuan Shuyuan': 1,
#  'Guan Hai Ce Zhi Tie Qi Xiong Guan': 1,
#  'Bai Gui Youeryuan 3rd Season': 1,
#  'Bai Gui Youeryuan 2nd Season': 1,
#  'Bai Gui Youeryuan': 1,
#  'Omoide wa Kireide': 1,
#  'Bishoujo Senshi Sailor Moon S: Kotaete Moon Call!': 1,
#  'Mine': 1,
#  'Everlasting Snow': 1,
#  'Kimi wo Matsu': 1,
#  'Polaris': 1,
#  'Gu Xiong: Huo Qi': 1,
#  'Hei Mao Jing Zhan Zhi Fei Cui Zhi Xing': 1,
#  'Saikyou Kamizmode!': 1,
#  "Kamen Rider Zero-One: Short Anime - Everyone's Daily Life": 1,
#  'Bokutachi wa Benkyou ga Dekinai! Chapel no Kane wa [X] wo Shukufuku Suru': 1,
#  'Ookami-san wa Taberaretai': 1,
#  'Cardfight!! Vanguard: overDress': 1,
#  'Anime Kapibara-san': 1,
#  'Zhandouban Geji!': 1,
#  'Mamoru Hikitsugu Watashitachi no Kurashi': 1,
#  'World Witches Hasshin Shimasu!': 1,
#  'Hello Kitty no Kaguya-hime (2001)': 1,
#  'Tadaima! Chibi Godzilla': 1,
#  'Hawk no Onayami Soudanshitsu': 1,
#  'Zhandou Wang Zhi Jufeng Zhan Hun 5': 1,
#  'Wasureta Furi wo Shite': 1,
#  'Runway de Waratte Mini Anime': 1,
#  'Shadowverse Recaps': 1,
#  'Miao Xiansheng': 1,
#  'Tsumamareru Koma': 1,
#  'Iikaereba': 1,
#  'Seizei Ganbare! Mahou Shoujo Kurumi 3rd Season': 1,
#  'Yeon-ae Halujeon Zero': 1,
#  'Meitantei Conan: Shakunetsu no Ginga Tetsudou': 1,
#  'Yewai de Zaoyu': 1,
#  'Xiao Xiong De Lu Xing': 1,
#  'Arifureta Shokugyou de Sekai Saikyou 2nd Season': 1,
#  'Hao Gua Gua': 1,
#  'Huo Tong': 1,
#  'Jia Er Mai Xing': 1,
#  'Xiao Ming Xing': 1,
#  'Hakumei no Tsubasa: Expansion - Hoshi no Matsuri': 1,
#  'Oba Ano Omamori': 1,
#  'Soprano Rain': 1,
#  'Fire Emblem Heroes Book III Movie：Cohort of the Dead': 1,
#  'Chu Xi De Gushi': 1,
#  'Tsurune Movie: Hajimari no Issha': 1,
#  'Dr. Stone: Stone Wars - Kaisen Zenya Special Eizou': 1,
#  'Kuailede Shuzi': 1,
#  'Osampo': 1,
#  'Yume Miteru Wake ja Nai yo': 1,
#  'Xiao Huli': 1,
#  'Ma Feng Wo': 1,
#  'Han Niu Yu Mu Tong': 1,
#  'San Shi Liu Ge Zi': 1,
#  'Guo Qiao': 1,
#  'Zhang Le Tui De Mang Guo': 1,
#  'Kan Men De Hei Gou': 1,
#  'Qian……': 1,
#  'Xiao Xiong Mai Xi Gua': 1,
#  'Shi Shi Zi': 1,
#  'Yuan Yuan De Qi Guai Lu Xing': 1,
#  'Zhong Li': 1,
#  'Ookina Furudokei (1973)': 1,
#  'DiSCOVER THE FUTURE': 1,
#  'Chuan Shu Zijiu Zhinan: Xian Meng Pian': 1,
#  'Ookina Furudokei': 1,
#  'Chao Ji Fei Zao': 1,
#  'Xin Zhuang De Men Ling': 1,
#  'Shui Lu': 1,
#  'Wang': 1,
#  'Lian Sheng San Ji': 1,
#  'Hetalia World★Stars': 1,
#  'Qiang Zhen Tou': 1,
#  'Yakusoku (2020)': 1,
#  'Nu Huo Bu Tian': 1,
#  'Mei Ya De Laohu': 1,
#  'Da Sao Chu': 1,
#  'Jiazi Jiu Lu': 1,
#  'Wupo, Eyu He Xiao Gu Niang': 1,
#  'Da Hua He Xiao Hua': 1,
#  'Hai Li Bu': 1,
#  'Cao Ren': 1,
#  'Lao Zhu Xuan Mao': 1,
#  'Lao Shu Jia Nu': 1,
#  'Yi Ye Fu Weng': 1,
#  'Houzi Diao Yu': 1,
#  'Wang Qi Dao Ci Yi You': 1,
#  'Mao Mi De Hu Zi': 1,
#  'Houzi Lao Yue': 1,
#  'Zhen Jia Li Kui': 1,
#  'Lao Shan Dao Shi': 1,
#  'Nan Guo Xian Sheng': 1,
#  'Xiao Xiao Ji Qi Ren': 1,
#  'Tai Lyu': 1,
#  'Shuai Xiang Lu': 1,
#  'Gu Dong Lai Le': 1,
#  'Shan Liang De Xia Wu Dong': 1,
#  'Long Ya Xing': 1,
#  'Mr. Fixer': 1,
#  'Yuan Yuan He Ji Qi Ren': 1,
#  'Xiao Ya Ga Ga': 1,
#  'San Zhi Lang': 1,
#  'Laolang Qingke': 1,
#  'Kita no Kaze to Taiyou to': 1,
#  'Toaru Kagaku no Railgun T: Motto Marutto Railgun': 1,
#  'With My Umbrella': 1,
#  'Your Thorn': 1,
#  'Alice Gear Aegis: Doki! Actress Darake no Mermaid Grand Prix♥': 1,
#  'Xiao Hong Lian He Xiao Lan Lian': 1,
#  'Cao Chong Cheng Xiang': 1,
#  'Gekka Bijin (Music)': 1,
#  'Qi Guai De Shou': 1,
#  'Xiao Song Shu Li Fa Shi': 1,
#  'Xiao Ba Jie': 1,
#  'Mushi no Tsubuyaki': 1,
#  'Anata ga Mieru': 1,
#  'Zhuo Mi Cang': 1,
#  'Hu Die Quan': 1,
#  'Tsuki ga Michibiku Isekai Douchuu': 1,
#  'Leo': 1,
#  'Xiao Xiongmao Xue Mu Jiang': 1,
#  'Huli Song Putao': 1,
#  'Jia Ru Wo Shi Wu Song': 1,
#  'Qu Qu': 1,
#  'Wasshoi Nippon': 1,
#  'Lang Lai Le': 1,
#  'Zhi Ren Guo': 1,
#  'Mang Nu Yu Huli': 1,
#  'Hui Sheng: Xiao Tu Tao Tao De Gushi': 1,
#  'Lao Hu Xue Yi': 1,
#  'Tao Qi De Jin Si Hou': 1,
#  'Ookina Furudokei (2002)': 1,
#  'Xiao Cai Feng': 1,
#  'Cuxin de Xiaopang': 1,
#  'Qiyi De Menggu Ma': 1,
#  'Boku no Hero Academia the Movie 2: Heroes:Rising - Epilogue Plus - Yume wo Genjitsu ni': 1,
#  'Koneko no Byouki': 1,
#  'Dahong Ying': 1,
#  'Xiao Jingling Hui Dou': 1,
#  'Xingxing Tan Zhang': 1,
#  'Kuai Yue Jia Jia Che': 1,
#  'Zigu Yingxiong Chu Shaonian': 1,
#  'Shi Er Shengxiao': 1,
#  'Hong Bizi': 1,
#  'Yinshen Tan Zhang': 1,
#  'Tebie Chedui': 1,
#  'Mofang Dasha': 1,
#  'Lu He Niu': 1,
#  'Xiao Dingzi': 1,
#  'Yīban Er': 1,
#  'Dongtian Li De Xiaotian Shu': 1,
#  'Qi Niu Nan Xia': 1,
#  'Zhong Shu': 1,
#  'Ai Ni': 1,
#  'Gudu De Lily': 1,
#  'Senlin, Xiaoniao He Wo': 1,
#  'Semi wa Magic Cube': 1,
#  'Kumo': 1,
#  'Boku no Nikkichou': 1,
#  'Tell the Story to You': 1,
#  'Ayanami Rei, Hajimete no Kuchibeni': 1,
#  'Hamigaki Ondo': 1,
#  'Attack Zero x Evangelion': 1,
#  'Getter Robo Arc': 1,
#  'Idol Shineitai': 1,
#  'Cue!': 1,
#  'Semi wa Magic Cube 2nd Season': 1,
#  'Eiyuuou, Bu wo Kiwameru Tame Tenseisu: Soshite, Sekai Saikyou no Minarai Kishi♀ Mini Anime': 1,
#  'Ai wo Komete': 1,
#  'Juunenbun no Watashi e': 1,
#  'Tenkuu Shinpan': 1,
#  'Tomato Confit': 1,
#  'Hong Gildong Janggun': 1,
#  'Doraon Yeongung Hong Gildong': 1,
#  'Yasuke': 1,
#  'Bad Mood': 1,
#  'Rilakkuma to Yuuenchi': 1,
#  'Thermae Romae Novae': 1,
#  'Gokushufudou': 1,
#  'Kageki Shoujo!!': 1,
#  'Shuke He Beita': 1,
#  'Senlin Li De Jin Yueliang': 1,
#  'Xiao Tu Tao Tao De Gushi: Bu Pa Leng De Da Yi': 1,
#  'Ben Gouxiong': 1,
#  'Tokyo Babylon 2021': 1,
#  'Kazaguruma (1996)': 1,
#  'Houkiboshi (2012)': 1,
#  'Jue Shi Wu Hun': 1,
#  'Yue Dayue Xiang': 1,
#  'Xuanmei Ji': 1,
#  'Laohu Zhuang Ya': 1,
#  'Mama Qing Xiuxi': 1,
#  'Koushin': 1,
#  'Feixiang De Gezi': 1,
#  'Xue Shizi': 1,
#  'You Qiu Bi Ying': 1,
#  'Mayi He Da Xiang': 1,
#  'Qiao Zai Qi Zhong': 1,
#  'Lata Dawang Qiyu Ji (Movie)': 1,
#  'Lata Dawang Qiyu Ji': 1,
#  'Hulu Xiongdi (Movie)': 1,
#  'Xin Hulu Xiongdi': 1,
#  'Qi Ren You Tian': 1,
#  'Kaguya-sama wa Kokurasetai? Tensai-tachi no Renai Zunousen OVA': 1,
#  'Kaguya-sama wa Kokurasetai: Ultra Romantic': 1,
#  'Houzi Dian Bianpao': 1,
#  'Xiang Hu': 1,
#  'Ying': 1,
#  'Zhengzhi': 1,
#  'Hong Qiqiu': 1,
#  'Xiao Xiao Huajia': 1,
#  'Aaron He Lili': 1,
#  'Lanhua Hua': 1,
#  'Yiban Er Wangguo': 1,
#  'Gao Nuren He Ai Zhangfu': 1,
#  'Baxian Yu Tiaozao': 1,
#  'Anning': 1,
#  'Jinbi Guo Youji': 1,
#  'Du Mu Qiao': 1,
#  'Poshui Jie De Chuanshuo': 1,
#  'Gudu De Xiao Zhu': 1,
#  'Xiao E Yu Hong Fangzi': 1,
#  'Bupiao': 1,
#  'Lan Gu': 1,
#  'Pi Pi De Gushi': 1,
#  'Douji': 1,
#  'Zhui Shu': 1,
#  'Qiangzhe Shanggou': 1,
#  'Yu': 1,
#  'Zoning Tokyo': 1,
#  'The Movement': 1,
#  'Rikei ga Koi ni Ochita no de Shoumei shitemita. Heart': 1,
#  'Mu Yang Shao Nian': 1,
#  'McDull: Niu Hua Chen': 1,
#  'Lan Pi Shu Yu Da Lian Mao 2nd Season': 1,
#  'Lan Pi Shu Yu Da Lian Mao': 1,
#  'Dan Zhu Chuan Shuo': 1,
#  'Zhi Duoduo: Jieri Jianianhua': 1,
#  'Yi Fei Chong Tian: Tianji Zhang Qi': 1,
#  'Lei Su Deng: Yi Fei Chong Tian': 1,
#  'Wonder Egg Priority': 1,
#  'Da Zhentan Fuermosi: Tao Yu Da Zhuibu': 1,
#  'Kaitai Shita Inu no Blues': 1,
#  'Toriaezu, Tamade.': 1,
#  'Mu Wang Zhi Wang: You Du Zhan': 1,
#  'Tsukiusa. Gekijou': 1,
#  'Deng Mingtian': 1,
#  'Xiao Xiliu': 1,
#  'Shuide Benling Da': 1,
#  'Taiyang de Xiao Keren': 1,
#  'Renshen Wawa': 1,
#  'Da Jiangzhang': 1,
#  'Xiao Yanzi': 1,
#  'Mu Tong Yu Gongzhu': 1,
#  'McDull: Niu Hua Che Specials': 1,
#  'McDull: Kuaile Di Tan': 1,
#  'Fan Dou Gao Bi Wan Zhuan Sheng Dan Cheng 3D': 1,
#  'Wengzhong Zhuobie': 1,
#  'Sekikashita Kusanagi': 1,
#  'Meitounao He Bugaoxing (TV)': 1,
#  'Meitounao He Bugaoxing': 1,
#  'Yike Da Baicai': 1,
#  'Si Yaodai': 1,
#  'Hong Yunya': 1,
#  'Xiao Xiao Ying Xiong': 1,
#  'Xiaomao Diaoyu': 1,
#  'Xiao Tiezhu': 1,
#  'Di Kang': 1,
#  'Because': 1,
#  'Fei Lai Fu': 1,
#  'Zhi Ren Dao Luan Ji': 1,
#  'Da Nao Hua Shi': 1,
#  'Yuukoku no Moriarty Part 2': 1,
#  'Timeless Tree': 1,
#  'Yue Chen': 1,
#  "Cancerfund x Din Dong CM's": 1,
#  'Di Di Zi Zhou Ji II': 1,
#  'Di Di Zi Zhou Ji': 1,
#  'Cong Ming De Yazi': 1,
#  'Yuan Xing Bi Lu': 1,
#  'Hei Xiong Qi Yu Ji': 1,
#  'Da Luo Bo': 1,
#  'Guo Hou Shan': 1,
#  'Qiang Shang De Hua': 1,
#  'Zhu Bajie Chi Xigua': 1,
#  'Gu Boshi Di Xin Fa Xian': 1,
#  'Zhao Xiao Ge Ge': 1,
#  'Huo Yan Shan': 1,
#  'Xiao Fa Ming Jia': 1,
#  'Shui Chang De Zui Hao': 1,
#  'Mei Li De Xiao Jin Yu': 1,
#  'Lao Po Po De Zao Shu': 1,
#  'Xiao Li Yu Tiao Long Men': 1,
#  'Xiao Pengyou Men': 1,
#  'Yi Ge Xin Zu Qiu': 1,
#  'Shuang Bao Tai': 1,
#  'Godzilla: S.P': 1,
#  'San Ge Linju': 1,
#  'Pangsao Hui Niangjia': 1,
#  'Jin Erhuan He Yin Chutou': 1,
#  'Da Honghua': 1,
#  'Jizhi de Shanyang': 1,
#  'Wo Zhidao': 1,
#  'Xiao Hou Yu Bai Pang': 1,
#  'Si Zhi Xiao Ye Ya': 1,
#  'Da Lie Ji': 1,
#  'Bu Gu Niao Jiao Chi Le': 1,
#  'Pa Xiu De Huang Ying': 1,
#  'Shui Mo Donghua Pian Duan': 1,
#  'Shan Yang He Lang': 1,
#  'Gezi': 1,
#  'Hong Se Xin Hao': 1,
#  'San Zhi Hu Die': 1,
#  'Ji Gong Dou Xi Shuai': 1,
#  'Gui Hou Fen Shu': 1,
#  'Yi Fu Tong Jin': 1,
#  'Yi Zhi Xie': 1,
#  'San Mao Liu Lang Ji': 1,
#  'Longxia': 1,
#  'Kan Chai Gu Niang': 1,
#  'Senlin Zhi Wang': 1,
#  'Mi Feng Yu Qiu Yin': 1,
#  'Luo Bo Hui Lai Le': 1,
#  'San Mao Luxing Ji': 1,
#  'San Mao Lixian Ji': 1,
#  'San Mao Qiyu Ji': 1,
#  'San Mao Liu Lang Ji (TV)': 1,
#  'Gebäude Bäude': 1,
#  'Sign (2019)': 1,
#  'Sparkle': 1,
#  'Bear Bear Bear Kuma!': 1,
#  'Alice no Kisetsu': 1,
#  'Umi no Uta': 1,
#  'Henkei Sakuhin Dai 5-ban: Rembrandt no Shudai ni yoru Henkei Kaitai to Saikousei': 1,
#  'Yamakawa Keiko-san wa Furimukanai': 1,
#  'Matierica': 1,
#  'Youkina Fuukei-tachi': 1,
#  'Taimanin Asagi: Toraware no Niku Ningyou': 1,
#  'Yubi no Sukima-chan': 1,
#  'Citrus (Music)': 1,
#  'Pocari Sweat Run Carnival 2019': 1,
#  'Kaoru no Taisetsu na Mono': 1,
#  'Kanchigaisei Han Kiboushou feat. Hatsune Miku': 1,
#  'Chiyuki no Fashion Check': 1,
#  'Qiguai de Qiusai': 1,
#  'Miao Wu Shi Shui Jiao De?': 1,
#  'Ci Wei Bei Xi Gua': 1,
#  'Xiongmao Bai Huo Shang Dian': 1,
#  'Yu Ren Mai Xie': 1,
#  'Mu Ji Ban Jia': 1,
#  'Tian Cai Za Ji Yan Yuan': 1,
#  'Liang Zhang Bu Gao': 1,
#  'Shuo Feng: Po Zhen Zi': 1,
#  'Mela!': 1,
#  'Haiiro no Saga': 1,
#  'Ding Ding Zhan Hou Wang': 1,
#  'Ajisai no Chiru Koro ni': 1,
#  'Himawari wa Yoru ni Saku': 1,
#  'Ijirare: Fukushuu Saimin': 1,
#  'Zhe Shi Yi Shou Ge': 1,
#  'Zhang Fei Shen Gua': 1,
#  'Hei Gong Ji': 1,
#  'Xiao Ma Hu': 1,
#  'Chui Gu Shou': 1,
#  'Jiao Jiao De Qi Yu': 1,
#  'Magic': 1,
#  'Shadows House': 1,
#  'Ba Bai Bian Zi': 1,
#  'Wo de Peng You Xiao Hai Tun': 1,
#  'Effendi Xin Chuan: Zhong Jin Ji': 1,
#  'Shao Nian Effendi': 1,
#  'Effendi Xin Chuan: Bu Ting Hua De Gou': 1,
#  'Lao Xiao Effendi': 1,
#  'Effendi De Gushi': 1,
#  'Shiroi Spitz': 1,
#  'Boukentai: Mori no Yuusha': 1,
#  'Xiang Bu Xiang?': 1,
#  'Qi Guai De Bing Hao': 1,
#  'Xi Gua Pao': 1,
#  'Bing Shang Yu Xian': 1,
#  'Wan Dun Shui Ya Ji Zhan Ge': 1,
#  'Xiao Ge Er Lia': 1,
#  'Nan Fang Shao Nian': 1,
#  'Li Ke Zhang Giao Nan Chui Shi Ban': 1,
#  'Wo Men Ai Nong Cun': 1,
#  'Hong Ling Jin': 1,
#  'Xiao Lin Riji': 1,
#  'Hu Shang Ge Wu': 1,
#  'Ban Ye Ji Jiao': 1,
#  'Lu Bian Xin Shi': 1,
#  'Dong Hai Xiao Shao Bing': 1,
#  'Hong Jun Qiao': 1,
#  'Cao Yuan Ying Xiong Xiao Jie Mei': 1,
#  'Cha Bu Duo': 1,
#  'Si Dian Ban': 1,
#  'Zhang Fa Mei': 1,
#  'Huang Jin Meng': 1,
#  'Jin Se De Hai Luo': 1,
#  'McDull and McMug': 1,
#  'Kongque Gongzhu': 1,
#  'Fang Xue Yi Hou': 1,
#  'Bu Cha Ban Fen Hao': 1,
#  'Xiao Bai Ge': 1,
#  'Da Lu De Gushi': 1,
#  'Hu Li Da Lieren': 1,
#  'Feather (Overdrive Version)': 1,
#  'Harmonia feat. Makoto': 1,
#  'Ge Sheng Fei Chu Wuzhishan': 1,
#  'Huo Hong De Yan Biao': 1,
#  'Hua Lang Yi Ye': 1,
#  'Xiao Shi Zhu': 1,
#  'Lu Dang Xiao Ying Xiong': 1,
#  'Shan Yang Hui Le Jia': 1,
#  'Jin Se De Da Yan': 1,
#  'Xiao Hao Shou': 1,
#  'Dalbitkungkwol': 1,
#  'Zhang Zai Wu Li De Zhu Sun': 1,
#  'Around the World!': 1,
#  'Chu Fa Zhi Qian': 1,
#  'Da Chao Xun Zhi Ye': 1,
#  'Jun Ma Fei Teng': 1,
#  'Du Kou': 1,
#  'Xiao Balu': 1,
#  'Dai Xiang De Gong Jian': 1,
#  'Shikiyoku Infinite': 1,
#  'Oujo & Onna Kishi W Do Gehin Roshutsu': 1,
#  'Condom Battler Gorou': 1,
#  'Bungou to Alchemist: Shinpan no Haguruma': 1,
#  'Kuma Kuma Kuma Bear': 1,
#  'Newsong': 1,
#  'A-ra-shi: Reborn': 1,
#  'Jintian Kaishi Zuo Mingxing': 1,
#  'Bang!Bang!Bang!': 1,
#  'Ling Jian Zun 3rd Season': 1,
#  'Back Arrow': 1,
#  'Hortensia Saga': 1,
#  'Cheat Kusushi no Slow Life: Isekai ni Tsukurou Drugstore': 1,
#  'Jitaku Keibiin 2': 1,
#  'Rail Romanesque': 1,
#  'Shin Chuuka Ichiban! 2nd Season': 1,
#  'Enen no Shouboutai: Ni no Shou': 1,
#  'Lalalacoco': 1,
#  "Phantasy Star Online 2: Episode Oracle - Xiao's Report": 1,
#  'Gundam Build Divers Re:Rise 2nd Season': 1,
#  'Sexfriend Gakuen': 1,
#  'Zenonzard The Animation': 1,
#  'Marumaru Manul': 1,
#  'Hige wo Soru. Soshite Joshikousei wo Hirou.': 1,
#  'Ore wo Suki nano wa Omae dake ka yo: Oretachi no Game Set': 1,
#  'Yingxiong Zai Lin': 1,
#  'Fate/strange Fake PV': 1,
#  'Hakushon Daimaou 2020': 1,
#  'Fumetsu no Anata e': 1,
#  'Kimagure Orange☆Road: Summarized Edition': 1,
#  'Vanilla': 1,
#  'Melty Land Nightmare': 1,
#  'Meryuu': 1,
#  'Umiyuri Kaiteitan': 1,
#  'Evangelion Shito, Hakata Shuurai': 1,
#  'Amrita no Kyouen': 1,
#  'Sore Ike! Anpanman: Fuwa Fuwa Fuwaly to Kumo no Kuni': 1,
#  'Kaiketsu Zorori no Kyoufu no Hanayome Sakusen': 1,
#  'Negative Shinkaron feat. Hatsune Miku': 1,
#  'Koisuru Asteroid: Kirakira Zoukan-gou': 1,
#  'Mousou Kanshou Daishou Renmei feat. Hatsune Miku': 1,
#  'Duel Masters Zero: Tokubetsu-hen - Tamashii Shoukan Special!': 1,
#  'Psychogram feat. Hatsune Miku': 1,
#  'Murenase! Seton Gakuen Special': 1,
#  'Higurashi no Naku Koro ni Gou': 1,
#  'Hentatsu (TV)': 1,
#  'Ni Zai Xing Guang Shen Chu': 1,
#  'Xue Ying Ling Zhu Zhi Qi Yu Pian': 1,
#  'Touhokutou, Juunana no Sora': 1,
#  'Beastars 2nd Season': 1,
#  'Null Peta: Doki♥ Nurunuru Petapeta! Mizugi-darake no Oneechan Taikai!': 1,
#  'Dreamless Dreams': 1,
#  'Azur Lane: Bisoku Zenshin!': 1,
#  'Pokemon Movie 23: Koko': 1,
#  'Kiratto Pri☆chan Season 3': 1,
#  'Love Live! Nijigasaki Gakuen School Idol Doukoukai': 1,
#  'Suki tte Nandarou... Namida': 1,
#  'Ai Zai Xiyuan Qian': 1,
#  'Granblue Fantasy The Animation Season 2 Extras': 1,
#  'SSSS.Dynazenon': 1,
#  'Chanto...': 1,
#  'Chikatetsu no Doutai': 1,
#  'Oshiri Tantei Movie 2: Tentoumushi Iseki no Nazo': 1,
#  'Hakumei no Tsubasa': 1,
#  'Gottsuo-sama': 1,
#  'Psycho-Pass 3: First Inspector': 1,
#  'Hajimete no Hitozuma': 1,
#  'BanG Dream! Garupa☆Pico: Oomori': 1,
#  'Stand By Me Doraemon 2': 1,
#  'Dr. Stone: Stone Wars': 1,
#  'Sagashimono (ONA)': 1,
#  'Breakers': 1,
#  'Shinchou Yuusha: Kono Yuusha ga Ore Tueee Kuse ni Shinchou Sugiru Recap': 1,
#  'Marudase Kintarou': 1,
#  'Can Ci Pin: Fangzhu Xingkong': 1,
#  'Kidou Senshi Gakuen: Kaettekita G-Reco Koushien': 1,
#  'Teleport': 1,
#  'World Trigger 2nd Season': 1,
#  'Doko kara Kita no': 1,
#  '22/7: 8＋3=?': 1,
#  'Inmou': 1,
#  'Urashimasakatasen no Nichijou Special': 1,
#  'Kappapa': 1,
#  'Aishite Aishite Aishite': 1,
#  'Yuukoku no Moriarty': 1,
#  'Wan Jie Xian Zong 3rd Season': 1,
#  'Kemono Jihen': 1,
#  'Dragon Quest: Dai no Daibouken (2020)': 1,
#  'Gundam: G no Reconguista Movie II - Bellri Gekishin': 1,
#  'Tsuki no Buranko': 1,
#  'Bokutachi no Remake': 1,
#  'Riyuu': 1,
#  'Shokugeki no Souma: Gou no Sara': 1,
#  'Toji no Miko: Kizamishi Issen no Tomoshibi': 1,
#  'Mr.AFFECTiON': 1,
#  'Marulk-chan no Nichijou': 1,
#  'Kyokou Suiri Mini Anime': 1,
#  'Komatta Jiisan': 1,
#  'Great Teacher Onizuka Recaps': 1,
#  'Jie Yao': 1,
#  'Ujudaejang Aekkunun': 1,
#  'Kobara Support x Kamiusagi Rope': 1,
#  'Kumo to Yuurei': 1,
#  'Juntoumei Shounen': 1,
#  'Parade (2019)': 1,
#  'Hitchcock': 1,
#  'Watashi no Tenshi': 1,
#  'Muku na Kisetsu': 1,
#  'Ryou': 1,
#  'Love Live! Superstar!!': 1,
#  'Nakitai Watashi wa Neko wo Kaburu': 1,
#  'Crescent Rise': 1,
#  'Ruru-chan no Jisatsu Haishin': 1,
#  'Leonardo Hakase to Kirin-mura no Nakama desho: Halloween Party da yo Kirin-mura!': 1,
#  'Leonardo Hakase to Kirin-mura no Nakama desho': 1,
#  'Leonardo Hakase to Kirin-mura no Nakama-tachi (TV)': 1,
#  'Leonardo Hakase to Kirin-mura no Nakama-tachi': 1,
#  'Kirakira Shougakusei Celeb-chan': 1,
#  'Naze Nani!? Asterisk': 1,
#  'Kandagawa Jet Girls: Koko kara Hajimaru Tokyo Girls Promotion': 1,
#  'Princess Principal: Crown Handler Movie 3': 1,
#  'Princess Principal: Crown Handler Movie 2': 1,
#  'Neppuu Kairiku Bushi Road: Kibou e no Michi': 1,
#  'Ame to Cappuccino': 1,
#  'Dakara Boku wa Ongaku wo Yameta': 1,
#  'Love Live! Sunshine!! Photo Session': 1,
#  'Ninja Box 2nd Season': 1,
#  'Fukai ni Nemuru Oujo no Abaddon The Animation': 1,
#  'Wan Jie Shen Zhu 2nd Season': 1,
#  'Tenioha! 2: Limit Over - Mada Mada Ippai, Ecchi Shiyo? The Animation': 1,
#  'Digimon Adventure: 20-shuunen Memorial Story': 1,
#  'Kouya no Kotobuki Hikoutai Kanzenban': 1,
#  'Mugen no Ryvius: Light': 1,
#  'Kokoro Magic "A to Z"': 1,
#  'Mai Mai Mai': 1,
#  'Suketto Sanjou!! The Animation': 1,
#  'Magical Love Potion!': 1,
#  'Mofumofuiction': 1,
#  'Kokoro Yohou': 1,
#  "Darwin's Game: Log Line": 1,
#  'Star Night Snow': 1,
#  'Wena Wrist': 1,
#  'Hikaru no Go Recaps': 1,
#  'Annyeong, Tyrano: Yeong-wonhi, Hamkke': 1,
#  '30-pun de Wakaru! Kore made no Love Live! Sunshine!!': 1,
#  'CP': 1,
#  'Kirakira Shougakusei Celeb-chan Specials': 1,
#  'Battle Spirits: Kakumei no Galette': 1,
#  'Dream': 1,
#  'Osomatsu-san Movie: Zensetsu Gekijou': 1,
#  'Tokyo Autumn Session': 1,
#  'Tanitsu Shikousei Overbloom': 1,
#  '"Star"t': 1,
#  'Made in Abyss: Retsujitsu no Ougonkyou': 1,
#  'Dou Hun Wei Zhi Xuan Yue Qiyuan III': 1,
#  'Jue Ming Xiang Ying': 1,
#  'Dou Hun Wei Zhi Xuan Yue Qiyuan II': 1,
#  'Dou Hun Wei Zhi Xuan Yue Qiyuan': 1,
#  'Kono Aozora ni Yakusoku wo: Youkoso Tsugumi Ryou e - Ai no Tsugumi Ryou Gekijou': 1,
#  'Code Geass: Hangyaku no Lelouch DVD Magazine Picture Drama': 1,
#  'Digimon Adventure:': 1,
#  'Banzai Rizing!': 1,
#  'Gin no Yuri': 1,
#  'AAside': 1,
#  'Texhnolyze: Revisit': 1,
#  'Kidou Senshi Gundam G40': 1,
#  'Tomica Kizuna Gattai: Earth Granner': 1,
#  'Heya Camp△: Sauna to Gohan to Sanrin Bike': 1,
#  '"Inochi Sketch" Movie Jabow x Mameshiba Collab CM': 1,
#  'Mameshiba x Nanatsu no Taizai Collab CM': 1,
#  'High & Low: G-Sword (Special)': 1,
#  'Dorohedoro: Ma no Omake': 1,
#  'Minna e wo Check!': 1,
#  'Yao Jing Zhong Zhi Shou Ce': 1,
#  'Xian Wang de Richang Shenghuo': 1,
#  'Soba Dokan': 1,
#  'Zashiki Warashi no Tatami-chan': 1,
#  'Overman King Gainer Recap': 1,
#  'Fugou Keiji: Balance:Unlimited': 1,
#  'Kakuza Tousan Specials': 1,
#  'Kakuza Tousan': 1,
#  'Gozonji! Kakuza Tousan': 1,
#  'Kakugen! Kakuza Tousan': 1,
#  'Arms Rally': 1,
#  'Olga no Russia-go Kouza': 1,
#  'Tobidase! Dokan-kun Specials': 1,
#  'Inunaki-mura x Taka no Tsumedan': 1,
#  'Dennou Senshi Dokan-kun: Champ Dokan': 1,
#  'Log Horizon: Entaku Houkai': 1,
#  'Chihayafuru 3: Ima Hitotabi no': 1,
#  'Koi to Yobu ni wa Kimochi Warui': 1,
#  'Suna no Akari': 1,
#  'Poccolies': 1,
#  'Keshikko': 1,
#  'Re-raise': 1,
#  'Motto Shitte Fukushima!': 1,
#  'Fantastic World': 1,
#  'Idoly Pride': 1,
#  'Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen OVA': 1,
#  'Sol Levante': 1,
#  'Seishun': 1,
#  'Peng Ran Xindong': 1,
#  'Saga Incident': 1,
#  'A Brightening Life': 1,
#  'Shobo Kujira Chibi Cobra': 1,
#  'Sayounara Concert': 1,
#  'Dokyuu Hentai HxEros': 1,
#  'Shimajirou no Wow! Movie 8: Shimajirou to Soratobu Fune': 1,
#  'Uramichi Oniisan': 1,
#  'Suppon Pon Pon': 1,
#  'Megane': 1,
#  'Umibe no Étranger': 1,
#  'Altered Carbon: Resleeved': 1,
#  'Pokke': 1,
#  "Healin' Good♡Precure": 1,
#  'Muv-Luv Alternative': 1,
#  'Captain Tsubasa (2018) Special': 1,
#  'My Boy': 1,
#  '7 Seeds 2nd Season': 1,
#  'Obaachan Moshikashite': 1,
#  ...}

# %% [markdown]
# Ta thấy rằng bộ dữ liệu có 2 bộ phim trùng tên là: Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian.

# %%
duplicate_titles = anime_df[anime_df['Title'] == "Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian"]
duplicate_titles
# Out:
#             ID                                     Title  Episodes Type  \
# 22752  53367.0  Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian      15.0  ONA
# 24119  55740.0  Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian      15.0  ONA
#
#                               Aired  \
# 22752  Jan 14, 2023 to Apr 15, 2023
# 24119  Jul 15, 2023 to Oct 14, 2023
#
#                                         Producers  Studios     Source  \
# 22752  iQIYI, High Energy Studio, Xuanshi Tangmen  CG Year  Web novel
# 24119                   iQIYI, High Energy Studio  CG Year  Web novel
#
#                 Genres         Duration  Score  Scored By     Rank  Popularity
# 22752  Action, Fantasy  20 min. per ep.   7.60      385.0  15502.0     14176.0
# 24119  Action, Fantasy  22 min. per ep.   7.46      262.0  20462.0     14602.0

# %% [markdown]
# Khi truy cập lại thông tin trên nền tảng MyAnimeList, ta thấy 2 bộ phim bị trùng tên có thể phân biệt dựa vào tên Tiếng Anh của chúng (English name). Do đó để tránh nhầm lẫn thông tin ta sẽ đổi giá trị cột Title của 2 bộ phim thành tên Tiếng Anh (dựa vào cột Aired).

# %%
# Sắp xếp các hàng trùng lặp theo thời gian 'Aired' (thời gian sớm hơn sẽ đứng trước)
duplicate_titles_sorted = duplicate_titles.sort_values(by='Aired')

# Cập nhật tên Title theo thứ tự đã sắp xếp
anime_df.loc[duplicate_titles_sorted.index[0], 'Title'] = "The Land of Miracles 2nd Season"
anime_df.loc[duplicate_titles_sorted.index[1], 'Title'] = "The Land of Miracles 3rd Season"

# Kiểm tra kết quả
print(anime_df[anime_df['Title'].str.contains("The Land of Miracles")])
# Out:
#             ID                            Title  Episodes Type  \
# 22752  53367.0  The Land of Miracles 2nd Season      15.0  ONA
# 24119  55740.0  The Land of Miracles 3rd Season      15.0  ONA
#
#                               Aired  \
# 22752  Jan 14, 2023 to Apr 15, 2023
# 24119  Jul 15, 2023 to Oct 14, 2023
#
#                                         Producers  Studios     Source  \
# 22752  iQIYI, High Energy Studio, Xuanshi Tangmen  CG Year  Web novel
# 24119                   iQIYI, High Energy Studio  CG Year  Web novel
#
#                 Genres         Duration  Score  Scored By     Rank  Popularity
# 22752  Action, Fantasy  20 min. per ep.   7.60      385.0  15502.0     14176.0
# 24119  Action, Fantasy  22 min. per ep.   7.46      262.0  20462.0     14602.0

# %% [markdown]
# #### Tiếp theo ta tính toán số lượng các cột có nhiều giá trị

# %% [markdown]
# Tương tự với cột đơn ta ta tiếp tục lưu tên các cột có nhiều giá trị vào `multi_columns`

# %%
multi_columns = ['Genres', 'Producers', 'Studios']

# %% [markdown]
# Sau đó tính giá trị thiếu của các cột này

# %%
for col in multi_columns:
    percentage_missing = (anime_df[col] == 'UNKNOWN').mean() * 100
    percentage_missing_dic[col] = percentage_missing
    print(f'Phần trăm giá trị còn thiếu của cột \'{col}\' là {percentage_missing:.2f}%')
# Out:
# Phần trăm giá trị còn thiếu của cột 'Genres' là 56.47%
# Phần trăm giá trị còn thiếu của cột 'Producers' là 52.15%
# Phần trăm giá trị còn thiếu của cột 'Studios' là 39.97%

# %% [markdown]
# Rõ ràng, ta nhận thấy rằng các giá trị của cột Producers và Studios có khá nhiều giá trị `UNKNOWN` có thể là do việc tìm kiếm thông tin của Producers hay Studios có thể bị bảo mật hoặc các anime không do các Producers và Studios chuyên nghiệp tổ chức.

# %% [markdown]
# Lưu số lượng giá trị khác nhau và đếm số lượng từng loại và lưu vào mảng `multiple_cate_profile`

# %%
# Tạo dataframe kết quả
def split_and_melt(column):
    df_split = column.str.split(', ', expand=True).melt().drop('variable', axis=1)
    return df_split['value']
long_df = anime_df[multi_columns].agg(split_and_melt)
distribution = long_df.agg(lambda column: pd.Series(column).value_counts().to_dict())
num_diff_vals = long_df.nunique()

# %%
multiple_cate_profile = pd.DataFrame(index=["num_diff_vals", "distribution"])
multiple_cate_profile[multi_columns] = [num_diff_vals, distribution]

multiple_cate_profile
# Out:
#                                                           Genres  \
# num_diff_vals                                                 22
# distribution   {'UNKNOWN': 14111, 'Comedy': 4624, 'Action': 4...
#
#                                                        Producers  \
# num_diff_vals                                               1618
# distribution   {'UNKNOWN': 13032, 'NHK': 1008, 'TV Tokyo': 62...
#
#                                                          Studios
# num_diff_vals                                               1133
# distribution   {'UNKNOWN': 9988, 'Toei Animation': 864, 'Sunr...

# %% [markdown]
# Ta có thể trích xuất cột thể loại để xem thử:

# %%
multiple_cate_profile.loc['distribution','Genres']
# Out:
# {'UNKNOWN': 14111,
#  'Comedy': 4624,
#  'Action': 4300,
#  'Fantasy': 3922,
#  'Adventure': 3476,
#  'Sci-Fi': 2794,
#  'Drama': 2168,
#  'Romance': 1720,
#  'Supernatural': 1212,
#  'Slice of Life': 836,
#  'Mystery': 809,
#  'Ecchi': 745,
#  'Horror': 464,
#  'Suspense': 373,
#  'Sports': 335,
#  'Hentai': 286,
#  'Award Winning': 231,
#  'Avant Garde': 198,
#  'Boys Love': 146,
#  'Gourmet': 132,
#  'Girls Love': 95,
#  'Erotica': 58}

# %% [markdown]
# Có tổng cộng 21 thể loại, 1617 producer, và 1132 Studios khác nhau còn các giá trị còn lại `UNKNOWN`.

# %% [markdown]
# #### Nhận xét chung

# %% [markdown]
# - Các giá trị của các cột và các hàng sau khi tiền xử lý không có gì bất thường, các con số đều phù hợp với ý nghĩa của từng cột dữ liệu.
# - Phần lớn các giá trị thiếu nằm ở ở các cột chứa thông tin của anime, điều này không quá bất ngờ vì khó mà có thể thu thập đủ dữ liệu của các anime mới ra hoặc các anime không nổi tiếng không được nhiều người biết tới.
# - Các cột Episodes, Type và Popularity có giá trị bị thiếu rất ít hoặc không có do đó các cột này rất có giá trị trong việc đánh giá và xử lý trong bộ dữ liệu này.
# - Các giá trị số các cột Score, Scored By, Rank là những thông tin hữu ích để đánh giá, xếp hạng anime. Tuy nhiên các cột này có tỉ lệ bị thiếu dữ liệu tương đối cao nên cần phải cân nhắc khi sử dụng chúng để phân tích dữ liệu.
# - Các cột số cũng có các khoảng giá trị phù hợp với tên cột.
# - Các cột có nhiều giá trị trong một ô là có số lượng giá trị bị mất nhiều nhất còn các cột phân loại có một giá trị thì hầu như dữ liệu rất đầy đủ. Cho thấy là thông tin Producers hay Studios của một anime có thể không được công bố hoặc rất khó để tìm kiếm thông tin này.

# %% [markdown]
# Vậy cuối cùng ta sẽ xuất file vừa tiền xử lý để dùng cho việc trả lời các câu hỏi.

# %%
anime_df.to_csv('anime_preprocessing.csv', index=False)
